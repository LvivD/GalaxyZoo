# %%
from dataloader_old import GalaxyZooDataset

# %%
import numpy as np
import pandas as pd
import os
from skimage import io

data_csv = "../data/training_solutions_rev1/training_solutions_rev1.csv"
root_dir = "../data/images_training_rev1"

csv_data = pd.read_csv(data_csv)

res = np.zeros((424,424,3), dtype=np.uint64)

n = len(csv_data)

for i in range(n):
    img_path = os.path.join(root_dir, str(csv_data["GalaxyID"][i]) + ".jpg")
    image = io.imread(img_path)
#     print(image)
    res += image
    if i%2000 == 0:
        print(i)
        
res_all = res
    
res //= n
# Out:
# 0
# 2000
# 4000
# 6000
# 8000
# 10000
# 12000
# 14000
# 16000
# 18000
# 20000
# 22000
# 24000
# 26000
# 28000
# 30000
# 32000
# 34000
# 36000
# 38000
# 40000
# 42000
# 44000
# 46000
# 48000
# 50000
# 52000
# 54000
# 56000
# 58000
# 60000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
io.imshow(res.astype('uint8'))
plt.show()

# %% [markdown]
# as we can see from dataset most of the data (galaxy) is only in 1/4 of the picture. So we can crop them without any data loss.

# %%
a = res

# %%
import matplotlib.pyplot as plt
plt.plot((a[212,:,0] + a[211,:,0])/2)
plt.plot(list(range(164,260)), ((a[212,164:260,0] + a[211,164:260,0])/2)-15)
plt.show()

# %%
plt.plot((a[:,212,0] + a[:,211,0])/2)
plt.plot(list(range(149,245)), ((a[149:245,212,0] + a[149:245,211,0])/2)-15)
plt.show()

# %%
plt.plot((a[212,:,0] + a[211,:,0])/2)
plt.plot(list(range(146,278)), ((a[212,146:278,0] + a[211,146:278,0])/2)-15)
plt.show()

# %%
plt.plot((a[212,:,0] + a[211,:,0])/2)
plt.plot(list(range(123,255)), ((a[212,123:255,0] + a[211,123:255,0])/2)-15)
plt.show()

# %%
plt.plot((a[:,212,0] + a[:,211,0])/2)
plt.show()

# %%
plt.plot((a[212,:,0] + a[211,:,0])/2)
plt.show()
